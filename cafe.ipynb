# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

import pandas as pd
import time

# %%
# creating an empty dataframe 
variables = {'cafe_name': str(), 'city': str(), 'province': str(), 'phone_number': str(), 'cost': int(), 'work_start': time,
'work_end': time, 'cafe_address': str(), 'hookah': bool(), 'internet': bool(), 'delivery': bool(), 'smoking': bool(), 'open_space': bool(), 'live_music': bool(), 'parking': bool(),
'pos': bool(), 'food_quality': int(), 'service': int(), 'cost_value': int(), 'environment': int(), 'follower': int(), 'lat': float(), 'lon': float()}
df_cafe = pd.DataFrame(variables, index=[])
df_cafe.dtypes
# Out:
# cafe_name        object
# city             object
# province         object
# phone_number     object
# cost              int64
# work_start       object
# work_end         object
# cafe_address     object
# hookah             bool
# internet           bool
# delivery           bool
# smoking            bool
# open_space         bool
# live_music         bool
# parking            bool
# pos                bool
# food_quality      int64
# service           int64
# cost_value        int64
# environment       int64
# follower          int64
# lat             float64
# lon             float64
# dtype: object

# %%
# function for convert to time
def changetime(time : 'str'):
    time = time.strip()
    if time == '24':
        time = '00'

    if ':' in time:
        newtime = datetime.strptime(time.strip(), '%H:%M').time()
    else:
        newtime = datetime.strptime(time.strip(), '%H').time()
    return newtime

# %%
# function for extract data from a cafe
def Data_cafe(URL, df_cafe, city):
    try:
        resp = requests.get(URL)
        html = resp.text
        soup = BeautifulSoup(html, "html.parser")

        cafe_name = soup.find('div', {'class': "venue-name-box"}).find('h1',{'property':'name'}).text

        province = ((soup.find('span', {'property': "address"}).text).split('،')[0].strip())[:30]

        phone_number = str(soup.find('span', {'property': "telephone"}).text.strip())

        cost = int(soup.find('div', {'class': "price-class"}).find_all('span')[-1].text)
    
        time_work = ((soup.find('ul', {'class': "infolist"}).find_all('li')[2].text).split()[3])
        if '/' in time_work:
            time_work = time_work.split('/')
            work_start = changetime(time_work[0].split('-')[0])
            work_end =changetime(time_work[1].split('-')[1])
        else:
            time_work = time_work.split('-')
            work_start = changetime(time_work[0])
            work_end =changetime(time_work[1])


        cafe_address = soup.find('span', {'property': "address"}).text.strip()

        features = soup.find('div', {'class': "venue-features-box"}).text

        hookah = False
        internet = False
        delivery = False
        smoking = False
        open_space = False
        live_music = False
        parking = False
        pos = False

        if "ارسال رایگان" in features:
            delivery = True
        if "دستگاه کارت خوان" in features:
            pos = True
        if "اینترنت رایگان" in features:
            internet = True
        if "سیگار" in features:
            smoking = True
        if "موسیقی زنده" in features:
            live_music = True
        if "قلیان" in features:
            hookah = True
        if "فضای باز" in features:
            open_space = True
        if "پارکینگ" in features:
            parking = True    

        food_quality = int((soup.find('ul', {'class': "rates-list"}) \
            .find_all('li')[0].find('div',{'class': 'rate-it'})).attrs['data-rateit-value'])

        service = int((soup.find('ul', {'class': "rates-list"}) \
            .find_all('li')[1].find('div',{'class': 'rate-it'})).attrs['data-rateit-value'])

        cost_value = int((soup.find('ul', {'class': "rates-list"}) \
            .find_all('li')[2].find('div',{'class': 'rate-it'})).attrs['data-rateit-value'])
        
        enviornment = int((soup.find('ul', {'class': "rates-list"}) \
            .find_all('li')[3].find('div',{'class': 'rate-it'})).attrs['data-rateit-value'])
        
        #followers find
        follower = soup.find('span', {'class': 'follow-count'})
        follower = follower.text.strip().replace('دنبال کننده', '')
        follower = int(follower.strip())
     

        #lat and lon
        location = soup.find('div', {'class': 'map-container'}).find('a')
        location = location.attrs['href'].strip().replace('http://www.google.com/maps/place/', '')
        location = location.split(',')
        lat = float(location[0])
        lon = float(location[1])
       

        new_raw = {'cafe_name': cafe_name, 'city': city, 'province': province, 'phone_number': phone_number, 'cost': cost,
        'work_start': work_start,'work_end': work_end, 'cafe_address': cafe_address, 'hookah': hookah, 'internet': internet,
        'delivery': delivery, 'smoking': smoking, 'open_space': open_space, 'live_music': live_music, 'parking': parking,
        'pos': pos, 'food_quality': food_quality, 'service':service, 'cost_value':cost_value, 'environment': enviornment,
        'follower': follower,'lat': lat, 'lon': lon}
        df_cafe = df_cafe.append(new_raw, ignore_index = True)
        
        
        
    except:
        pass
    return df_cafe

# %%
#function for extract links of cafe
def Cafes_link(URL, cafes_links, city):
    resp = requests.get(URL)
    html = resp.text
    soup = BeautifulSoup(html, "html.parser")
    
    for item in soup.find_all('div',{'class': 'restaurant-list-items span-4 th-span-6 mn-span-12'}):
        link = item.find('a', {'class': 'restaurant-link'}).attrs['href'] 
        if link not in cafes_links[city]:
            cafes_links[city].append(link)

    
    return cafes_links

# %%
#extract  cities_name and pages_number of them
URL = "https://fidilio.com/coffeeshops/in/tehran/"
resp = requests.get(URL)
html = resp.text
soup = BeautifulSoup(html, "html.parser")


cities = soup \
.find("select", {"id": "cityClass"}) \
.find_all("option")
cities_list = []
for option in cities:
    cities_list.append(option.attrs['value'])
print(cities_list)


CityPage = {}
for c in set(cities_list):
    URL = f"https://fidilio.com/coffeeshops/in/{c}/"
    resp = requests.get(URL)
    html = resp.text
    soup = BeautifulSoup(html, "html.parser")
    
    last_page = soup \
    .find("div", {"id": "container"}) \
    .find_all('a')[-1].attrs['href']

    
    URL = last_page
    resp = requests.get(URL)
    html = resp.text
    soup = BeautifulSoup(html, "html.parser")

    pages_max = soup \
    .find("div", {"id": "container"}) \
    .find_all('a')[-3].string
    CityPage[c] = int(pages_max)
    


print(CityPage)
# Out:
# ['tehran', 'shiraz', 'isfahan', 'mashhad', 'tabriz', 'kish', 'tehran', 'ghom', 'arak', 'ahwaz', 'sabzevar', 'urmia', 'zanjan', 'qazvin', 'hamedan', 'karaj', 'kerman', 'bandarabbas']
# {'tabriz': 1, 'urmia': 1, 'ahwaz': 2, 'zanjan': 1, 'tehran': 48, 'kish': 1, 'hamedan': 1, 'kerman': 1, 'karaj': 3, 'qazvin': 1, 'arak': 1, 'isfahan': 2, 'bandarabbas': 1, 'sabzevar': 1, 'shiraz': 2, 'ghom': 1, 'mashhad': 1}

# %%
#extract all page_links of each city
cafes_links = {}
for city,pages in CityPage.items():
    if city in cafes_links.keys():
        pass
    else:
        cafes_links[city] = []
    print(city)
    if pages > 1:
        for num in range(pages):
            URL = f"https://fidilio.com/coffeeshops/in/{city}/?p={num}"
            print(URL)
            Cafes_link(URL,cafes_links,city)
    else:
        URL = f"https://fidilio.com/coffeeshops/in/{city}/" 
        Cafes_link(URL,cafes_links,city)
# Out:
# tabriz
# urmia
# ahwaz
# https://fidilio.com/coffeeshops/in/ahwaz/?p=0
# https://fidilio.com/coffeeshops/in/ahwaz/?p=1
# zanjan
# tehran
# https://fidilio.com/coffeeshops/in/tehran/?p=0
# https://fidilio.com/coffeeshops/in/tehran/?p=1
# https://fidilio.com/coffeeshops/in/tehran/?p=2
# https://fidilio.com/coffeeshops/in/tehran/?p=3
# https://fidilio.com/coffeeshops/in/tehran/?p=4
# https://fidilio.com/coffeeshops/in/tehran/?p=5
# https://fidilio.com/coffeeshops/in/tehran/?p=6
# https://fidilio.com/coffeeshops/in/tehran/?p=7
# https://fidilio.com/coffeeshops/in/tehran/?p=8
# https://fidilio.com/coffeeshops/in/tehran/?p=9
# https://fidilio.com/coffeeshops/in/tehran/?p=10
# https://fidilio.com/coffeeshops/in/tehran/?p=11
# https://fidilio.com/coffeeshops/in/tehran/?p=12
# https://fidilio.com/coffeeshops/in/tehran/?p=13
# https://fidilio.com/coffeeshops/in/tehran/?p=14
# https://fidilio.com/coffeeshops/in/tehran/?p=15
# https://fidilio.com/coffeeshops/in/tehran/?p=16
# https://fidilio.com/coffeeshops/in/tehran/?p=17
# https://fidilio.com/coffeeshops/in/tehran/?p=18
# https://fidilio.com/coffeeshops/in/tehran/?p=19
# https://fidilio.com/coffeeshops/in/tehran/?p=20
# https://fidilio.com/coffeeshops/in/tehran/?p=21
# https://fidilio.com/coffeeshops/in/tehran/?p=22
# https://fidilio.com/coffeeshops/in/tehran/?p=23
# https://fidilio.com/coffeeshops/in/tehran/?p=24
# https://fidilio.com/coffeeshops/in/tehran/?p=25
# https://fidilio.com/coffeeshops/in/tehran/?p=26
# https://fidilio.com/coffeeshops/in/tehran/?p=27
# https://fidilio.com/coffeeshops/in/tehran/?p=28
# https://fidilio.com/coffeeshops/in/tehran/?p=29
# https://fidilio.com/coffeeshops/in/tehran/?p=30
# https://fidilio.com/coffeeshops/in/tehran/?p=31
# https://fidilio.com/coffeeshops/in/tehran/?p=32
# https://fidilio.com/coffeeshops/in/tehran/?p=33
# https://fidilio.com/coffeeshops/in/tehran/?p=34
# https://fidilio.com/coffeeshops/in/tehran/?p=35
# https://fidilio.com/coffeeshops/in/tehran/?p=36
# https://fidilio.com/coffeeshops/in/tehran/?p=37
# https://fidilio.com/coffeeshops/in/tehran/?p=38
# https://fidilio.com/coffeeshops/in/tehran/?p=39
# https://fidilio.com/coffeeshops/in/tehran/?p=40
# https://fidilio.com/coffeeshops/in/tehran/?p=41
# https://fidilio.com/coffeeshops/in/tehran/?p=42
# https://fidilio.com/coffeeshops/in/tehran/?p=43
# https://fidilio.com/coffeeshops/in/tehran/?p=44
# https://fidilio.com/coffeeshops/in/tehran/?p=45
# https://fidilio.com/coffeeshops/in/tehran/?p=46
# https://fidilio.com/coffeeshops/in/tehran/?p=47
# kish
# hamedan
# kerman
# karaj
# https://fidilio.com/coffeeshops/in/karaj/?p=0
# https://fidilio.com/coffeeshops/in/karaj/?p=1
# https://fidilio.com/coffeeshops/in/karaj/?p=2
# qazvin
# arak
# isfahan
# https://fidilio.com/coffeeshops/in/isfahan/?p=0
# https://fidilio.com/coffeeshops/in/isfahan/?p=1
# bandarabbas
# sabzevar
# shiraz
# https://fidilio.com/coffeeshops/in/shiraz/?p=0
# https://fidilio.com/coffeeshops/in/shiraz/?p=1
# ghom
# mashhad

# %%
#number of all cafes
summ = 0
for i,j in cafes_links.items():
    summ += len(j)

print(summ)
# Out:
# 1230

# %%
#send links to Data_cafe and at the end recive dataframe 
url ='https://fidilio.com'

for city, links in cafes_links.items():
    for link in links:
        URL = f"{url}{link}"
        df_cafe = Data_cafe(URL, df_cafe, city)

# %%
df_cafe
# Out:
#                cafe_name     city            province phone_number  cost  \
# 0          رولی (تبریز)    tabriz           اول عباسی  04135243397     2
# 1      لاله زار (تبریز)    tabriz             چایکنار  04132820831     2
# 2                 سانیز    tabriz             پل سنگی  04133346101     2
# 3                   آسا    tabriz              ولیعصر  04133314649     2
# 4          کلبه (تبریز)    tabriz              ولیعصر  04133249214     2
# ...                  ...      ...                 ...          ...   ...
# 1189               لئون   mashhad     بزرگراه کلانتری  09123848002     2
# 1190        رترو (مشهد)   mashhad        بلوار پیروزی     35098085     2
# 1191               1860   mashhad         هاشمیه 91/5     38814117     2
# 1192               نبات   mashhad  خیابان سلمان فارسی     38443918     2
# 1193            کافه 81   mashhad          بلوار سجاد  09155083007     2
#
#      work_start  work_end                                       cafe_address  \
# 0      11:00:00  23:00:00                            اول عباسی، به طرف منصور
# 1      11:00:00  23:00:00  چایکنار، بعد از کارواش شهرداری، نرسیده به بلوا...
# 2      11:00:00  23:00:00                                   پل سنگی، چایکنار
# 3      08:30:00  23:30:00  ولیعصر، خیابان شریعتی، نرسیده به میدان بهارستا...
# 4      10:00:00  23:30:00                                  ولیعصر، نگین پارک
# ...         ...       ...                                                ...
# 1189   10:00:00  23:45:00  بزرگراه کلانتری ، مجموعه توریستی آبادگران ، ای...
# 1190   13:30:00  00:00:00       بلوار پیروزی ، بین پیروزی 79 و 81 ، شماره 79
# 1191   17:00:00  23:30:00         هاشمیه 91/5 ، خیابان سوم سمت چپ ، قطعه آخر
# 1192   08:00:00  00:00:00  خیابان سلمان فارسی ، نرسیده به خیابان فلسطین ،...
# 1193   09:00:00  00:00:00        بلوار سجاد ، خیابان حامد جنوبی 9 ،  پلاک 81
#
#       hookah  internet  ...  live_music  parking   pos  food_quality  service  \
# 0      False     False  ...       False    False  True             0        0
# 1      False     False  ...       False    False  True             0        0
# 2      False     False  ...       False    False  True             0        0
# 3      False     False  ...       False    False  True             0        0
# 4      False      True  ...       False    False  True             0        0
# ...      ...       ...  ...         ...      ...   ...           ...      ...
# 1189   False      True  ...       False    False  True             0        0
# 1190   False      True  ...       False    False  True             0        0
# 1191   False      True  ...       False    False  True             4        4
# 1192   False      True  ...       False    False  True             5        4
# 1193   False     False  ...       False    False  True             1        4
#
#       cost_value  environment  follower        lat        lon
# 0              0            0         0  38.080036  46.308585
# 1              0            0         0  38.097036  46.271099
# 2              0            0         0  38.077004  46.316582
# 3              0            0         0  38.064740  46.359343
# 4              0            0         0  38.066835  46.351025
# ...          ...          ...       ...        ...        ...
# 1189           0            0         0  36.268532  59.551864
# 1190           0            0         0  36.332153  59.465501
# 1191           5            4         0  36.301612  59.485484
# 1192           4            3         0  36.305131  59.567860
# 1193           5            3         0  36.315477  59.545909
#
# [1194 rows x 23 columns]

# %%
df_cafe_1 = df_cafe.copy()

df_cafe_1.describe()
# Out:
#               cost  food_quality      service   cost_value  environment  \
# count  1194.000000   1194.000000  1194.000000  1194.000000  1194.000000
# mean      1.980737      2.118928     2.046901     2.157454     2.010050
# std       0.330811      2.158651     1.950643     2.021344     1.910372
# min       1.000000      0.000000     0.000000     0.000000     0.000000
# 25%       2.000000      0.000000     0.000000     0.000000     0.000000
# 50%       2.000000      3.000000     2.000000     3.000000     2.000000
# 75%       2.000000      4.000000     4.000000     4.000000     4.000000
# max       4.000000     31.000000     5.000000     5.000000     5.000000
#
#        follower          lat          lon
# count    1194.0  1194.000000  1194.000000
# mean        0.0    35.315069    51.438483
# std         0.0     1.650512     1.408558
# min         0.0    26.517163    45.038686
# 25%         0.0    35.707550    51.364851
# 50%         0.0    35.743834    51.413290
# 75%         0.0    35.782519    51.447233
# max         0.0    38.097036    59.572999

# %%
#fix food_quality where value is bigger than 5
df_cafe_1 =  df_cafe_1.drop_duplicates(keep='first').reset_index()
df_cafe_1.dtypes
df_cafe_1.groupby('food_quality').count()
def f(x):
    if x>5:
        return 5
df_cafe_1.loc[(df_cafe_1['food_quality'] >= 5),'food_quality'] = 5

df_cafe_1.describe()
# Out:
#              index         cost  food_quality      service   cost_value  \
# count  1194.000000  1194.000000   1194.000000  1194.000000  1194.000000
# mean    596.500000     1.980737      2.094640     2.046901     2.157454
# std     344.822418     0.330811      1.986186     1.950643     2.021344
# min       0.000000     1.000000      0.000000     0.000000     0.000000
# 25%     298.250000     2.000000      0.000000     0.000000     0.000000
# 50%     596.500000     2.000000      3.000000     2.000000     3.000000
# 75%     894.750000     2.000000      4.000000     4.000000     4.000000
# max    1193.000000     4.000000      5.000000     5.000000     5.000000
#
#        environment  follower          lat          lon
# count  1194.000000    1194.0  1194.000000  1194.000000
# mean      2.010050       0.0    35.315069    51.438483
# std       1.910372       0.0     1.650512     1.408558
# min       0.000000       0.0    26.517163    45.038686
# 25%       0.000000       0.0    35.707550    51.364851
# 50%       2.000000       0.0    35.743834    51.413290
# 75%       4.000000       0.0    35.782519    51.447233
# max       5.000000       0.0    38.097036    59.572999

# %%
df_cafe_1.to_csv('cafe_11.csv', index=False)

# %%
#fix data where is Nan
df_cafe_1['phone_number'] = df_cafe_1['phone_number'].fillna('0')
df_cafe_1.head()
# Out:
#    index           cafe_name    city   province phone_number  cost work_start  \
# 0      0       رولی (تبریز)   tabriz  اول عباسی  04135243397     2   11:00:00
# 1      1   لاله زار (تبریز)   tabriz    چایکنار  04132820831     2   11:00:00
# 2      2              سانیز   tabriz    پل سنگی  04133346101     2   11:00:00
# 3      3                آسا   tabriz     ولیعصر  04133314649     2   08:30:00
# 4      4       کلبه (تبریز)   tabriz     ولیعصر  04133249214     2   10:00:00
#
#    work_end                                       cafe_address  hookah  ...  \
# 0  23:00:00                            اول عباسی، به طرف منصور   False  ...
# 1  23:00:00  چایکنار، بعد از کارواش شهرداری، نرسیده به بلوا...   False  ...
# 2  23:00:00                                   پل سنگی، چایکنار   False  ...
# 3  23:30:00  ولیعصر، خیابان شریعتی، نرسیده به میدان بهارستا...   False  ...
# 4  23:30:00                                  ولیعصر، نگین پارک   False  ...
#
#    live_music  parking   pos  food_quality  service  cost_value  environment  \
# 0       False    False  True             0        0           0            0
# 1       False    False  True             0        0           0            0
# 2       False    False  True             0        0           0            0
# 3       False    False  True             0        0           0            0
# 4       False    False  True             0        0           0            0
#
#    follower        lat        lon
# 0         0  38.080036  46.308585
# 1         0  38.097036  46.271099
# 2         0  38.077004  46.316582
# 3         0  38.064740  46.359343
# 4         0  38.066835  46.351025
#
# [5 rows x 24 columns]

# %%
df_cafe_1.isna().sum()
# Out:
# index           0
# cafe_name       0
# city            0
# province        0
# phone_number    0
# cost            0
# work_start      0
# work_end        0
# cafe_address    0
# hookah          0
# internet        0
# delivery        0
# smoking         0
# open_space      0
# live_music      0
# parking         0
# pos             0
# food_quality    0
# service         0
# cost_value      0
# environment     0
# follower        0
# lat             0
# lon             0
# dtype: int64

# %%
#save data to Mysql
'''
from sqlalchemy import create_engine, Table, insert
import mysql.connector

user = 'user_group3'
password = 'hrsAWxaEJkIX_group3'
host = '45.139.10.138:80'
db = 'group3'

for index, row in df_cafe_1.iterrows():
    engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{db}")
    print(engine.table_names())
    query_1="INSERT INTO  group3.cafe (cafe_name ,city ,province ,phone_number, cost, work_start, work_end) VALUES(%s,%s,%s,%s,%s,%s,%s)"
    my_data_1=(row['cafe_name'],  row['city'],  row['province'],  row['phone_number'],row['cost'], row['work_start'], row['work_end'])
    id=engine.execute(query_1,my_data_1)

    cafe_id = id.lastrowid
    print("ID of Row Added  = ",id.lastrowid)
    
    query_2="INSERT INTO  group3.cafe_address (cafe_id, cafe_address) VALUES(%s,%s)"
    my_data_2=(cafe_id, row['cafe_address'])
    id_2 = engine.execute(query_2,my_data_2)


    query_3="INSERT INTO  group3.cafe_rating (cafe_id, food_quality, service_quality, cost, cost_value, environment) VALUES(%s,%s,%s,%s,%s,%s)"
    my_data_3=(cafe_id, row['food_quality'], row['service'], row['cost'], row['cost_value'], row['environment'])
    id_3 = engine.execute(query_3,my_data_3)


    query_4="INSERT INTO  group3.cafe_features (cafe_id, hookah, internet, delivery, smoking, open_space, live_music, parking, pos) VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    my_data_4=(cafe_id, row['hookah'], row['internet'], row['delivery'], row['smoking'], row['open_space'], row['live_music'], row['parking'], row['pos'])
    id_4 = engine.execute(query_4,my_data_4)
    '''
# Out:
# C:\Users\morte\AppData\Local\Temp\ipykernel_15140\3592569035.py:11: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(engine.table_names())
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  2
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  3
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  4
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  5
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  6
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  7
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  8
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  9
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  10
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  11
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  12
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  13
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  14
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  15
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  16
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  17
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  18
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  19
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  20
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  21
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  22
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  23
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  24
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  25
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  26
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  27
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  28
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  29
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  30
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  31
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  32
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  33
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  34
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  35
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  36
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  37
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  38
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  39
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  40
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  41
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  42
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  43
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  44
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  45
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  46
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  47
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  48
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  49
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  50
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  51
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  52
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  53
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  54
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  55
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  56
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  57
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  58
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  59
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  60
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  61
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  62
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  63
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  64
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  65
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  66
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  67
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  68
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  69
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  70
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  71
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  72
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  73
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  74
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  75
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  76
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  77
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  78
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  79
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  80
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  81
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  82
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  83
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  84
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  85
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  86
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  87
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  88
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  89
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  90
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  91
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  92
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  93
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  94
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  95
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  96
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  97
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  98
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  99
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  100
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  101
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  102
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  103
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  104
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  105
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  106
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  107
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  108
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  109
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  110
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  111
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  112
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  113
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  114
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  115
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  116
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  117
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  118
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  119
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  120
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  121
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  122
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  123
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  124
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  125
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  126
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  127
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  128
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  129
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  130
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  131
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  132
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  133
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  134
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  135
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  136
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  137
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  138
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  139
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  140
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  141
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  142
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  143
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  144
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  145
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  146
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  147
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  148
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  149
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  150
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  151
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  152
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  153
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  154
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  155
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  156
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  157
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  158
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  159
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  160
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  161
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  162
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  163
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  164
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  165
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  166
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  167
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  168
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  169
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  170
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  171
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  172
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  173
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  174
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  175
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  176
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  177
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  178
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  179
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  180
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  181
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  182
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  183
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  184
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  185
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  186
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  187
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  188
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  189
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  190
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  191
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  192
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  193
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  194
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  195
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  196
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  197
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  198
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  199
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  200
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  201
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  202
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  203
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  204
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  205
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  206
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  207
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  208
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  209
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  210
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  211
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  212
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  213
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  214
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  215
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  216
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  217
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  218
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  219
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  220
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  221
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  222
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  223
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  224
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  225
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  226
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  227
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  228
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  229
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  230
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  231
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  232
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  233
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  234
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  235
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  236
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  237
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  238
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  239
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  240
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  241
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  242
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  243
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  244
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  245
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  246
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  247
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  248
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  249
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  250
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  251
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  252
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  253
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  254
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  255
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  256
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  257
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  258
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  259
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  260
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  261
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  262
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  263
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  264
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  265
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  266
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  267
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  268
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  269
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  270
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  271
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  272
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  273
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  274
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  275
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  276
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  277
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  278
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  279
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  280
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  281
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  282
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  283
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  284
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  285
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  286
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  287
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  288
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  289
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  290
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  291
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  292
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  293
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  294
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  295
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  296
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  297
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  298
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  299
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  300
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  301
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  302
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  303
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  304
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  305
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  306
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  307
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  308
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  309
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  310
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  311
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  312
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  313
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  314
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  315
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  316
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  317
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  318
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  319
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  320
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  321
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  322
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  323
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  324
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  325
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  326
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  327
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  328
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  329
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  330
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  331
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  332
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  333
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  334
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  335
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  336
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  337
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  338
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  339
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  340
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  341
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  342
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  343
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  344
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  345
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  346
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  347
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  348
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  349
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  350
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  351
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  352
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  353
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  354
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  355
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  356
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  357
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  358
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  359
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  360
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  361
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  362
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  363
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  364
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  365
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  366
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  367
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  368
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  369
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  370
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  371
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  372
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  373
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  374
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  375
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  376
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  377
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  378
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  379
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  380
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  381
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  382
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  383
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  384
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  385
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  386
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  387
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  388
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  389
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  390
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  391
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  392
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  393
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  394
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  395
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  396
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  397
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  398
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  399
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  400
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  401
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  402
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  403
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  404
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  405
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  406
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  407
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  408
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  409
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  410
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  411
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  412
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  413
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  414
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  415
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  416
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  417
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  418
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  419
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  420
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  421
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  422
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  423
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  424
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  425
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  426
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  427
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  428
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  429
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  430
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  431
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  432
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  433
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  434
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  435
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  436
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  437
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  438
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  439
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  440
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  441
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  442
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  443
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  444
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  445
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  446
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  447
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  448
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  449
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  450
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  451
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  452
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  453
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  454
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  455
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  456
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  457
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  458
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  459
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  460
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  461
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  462
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  463
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  464
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  465
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  466
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  467
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  468
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  469
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  470
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  471
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  472
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  473
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  474
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  475
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  476
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  477
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  478
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  479
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  480
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  481
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  482
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  483
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  484
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  485
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  486
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  487
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  488
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  489
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  490
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  491
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  492
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  493
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  494
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  495
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  496
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  497
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  498
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  499
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  500
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  501
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  502
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  503
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  504
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  505
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  506
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  507
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  508
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  509
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  510
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  511
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  512
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  513
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  514
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  515
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  516
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  517
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  518
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  519
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  520
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  521
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  522
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  523
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  524
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  525
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  526
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  527
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  528
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  529
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  530
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  531
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  532
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  533
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  534
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  535
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  536
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  537
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  538
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  539
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  540
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  541
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  542
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  543
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  544
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  545
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  546
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  547
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  548
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  549
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  550
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  551
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  552
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  553
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  554
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  555
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  556
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  557
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  558
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  559
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  560
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  561
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  562
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  563
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  564
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  565
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  566
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  567
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  568
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  569
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  570
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  571
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  572
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  573
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  574
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  575
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  576
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  577
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  578
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  579
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  580
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  581
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  582
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  583
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  584
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  585
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  586
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  587
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  588
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  589
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  590
# ...
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  993
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  994
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  995
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  996
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  997
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  998
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  999
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1000
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1001
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1002
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1003
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1004
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1005
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1006
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1007
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1008
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1009
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1010
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1011
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1012
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1013
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1014
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1015
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1016
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1017
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1018
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1019
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1020
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1021
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1022
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1023
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1024
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1025
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1026
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1027
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1028
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1029
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1030
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1031
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1032
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1033
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1034
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1035
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1036
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1037
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1038
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1039
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1040
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1041
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1042
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1043
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1044
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1045
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1046
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1047
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1048
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1049
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1050
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1051
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1052
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1053
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1054
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1055
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1056
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1057
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1058
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1059
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1060
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1061
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1062
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1063
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1064
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1065
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1066
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1067
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1068
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1069
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1070
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1071
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1072
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1073
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1074
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1075
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1076
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1077
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1078
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1079
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1080
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1081
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1082
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1083
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1084
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1085
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1086
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1087
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1088
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1089
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1090
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1091
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1092
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1093
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1094
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1095
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1096
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1097
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1098
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1099
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1100
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1101
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1102
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1103
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1104
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1105
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1106
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1107
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1108
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1109
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1110
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1111
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1112
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1113
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1114
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1115
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1116
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1117
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1118
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1119
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1120
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1121
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1122
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1123
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1124
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1125
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1126
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1127
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1128
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1129
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1130
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1131
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1132
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1133
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1134
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1135
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1136
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1137
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1138
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1139
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1140
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1141
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1142
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1143
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1144
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1145
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1146
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1147
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1148
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1149
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1150
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1151
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1152
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1153
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1154
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1155
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1156
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1157
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1158
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1159
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1160
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1161
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1162
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1163
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1164
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1165
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1166
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1167
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1168
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1169
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1170
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1171
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1172
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1173
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1174
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1175
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1176
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1177
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1178
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1179
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1180
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1181
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1182
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1183
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1184
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1185
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1186
# ['cafe', 'cafe_address', 'cafe_features', 'cafe_rating']
# ID of Row Added  =  1187
